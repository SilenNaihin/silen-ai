# %%
# SGD vs RMSProp vs Momentum vs Adam vs AdamW

# %%
from silen_lib.utils.clean_mem import *

get_current_notebook_memory()
# Out:
# Current Notebook (PID: 27110):
#   Memory Usage: 78.50 MB (0.08 GB)
#   CPU Usage: 0.0%
#
# Largest variables in memory:
# 0.07666015625
